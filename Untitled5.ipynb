# %% [markdown]
# Objective :
# This case requires to develop a customer segmentation to give recommendations like saving plans, loans, wealth management, etc. on target customer groups.
#
# Data Description :
# The sample Dataset summarizes the usage behavior of about 9000 active credit card holders during the last 6 months. The file is at a customer level with 18 behavioral variables.
#
# Data :
# Use the below link to download the Data Set:here
#
# Attribute Information :
# Following is the Data Dictionary for customer's credit card dataset :-
#
# CUSTID : Identification of Credit Card holder (Categorical)
# BALANCE : Balance amount left in their account to make purchases
# BALANCEFREQUENCY : How frequently the Balance is updated, score between 0 and 1 (1 = frequently updated, 0 = not frequently updated)
# PURCHASES : Amount of purchases made from account
# ONEOFFPURCHASES : Maximum purchase amount done in one-go
# INSTALLMENTSPURCHASES : Amount of purchase done in installment
# CASHADVANCE : Cash in advance given by the user
# PURCHASESFREQUENCY : How frequently the Purchases are being made, score between 0 and 1 (1 = frequently purchased, 0 = not frequently purchased)
# ONEOFFPURCHASESFREQUENCY : How frequently Purchases are happening in one-go (1 = frequently purchased, 0 = not frequently purchased)
# PURCHASESINSTALLMENTSFREQUENCY : How frequently purchases in installments are being done (1 = frequently done, 0 = not frequently done)
# CASHADVANCEFREQUENCY : How frequently the cash in advance being paid
# CASHADVANCETRX : Number of Transactions made with "Cash in Advanced"
# PURCHASESTRX : Numbe of purchase transactions made
# CREDITLIMIT : Limit of Credit Card for user
# PAYMENTS : Amount of Payment done by user
# MINIMUM_PAYMENTS : Minimum amount of payments made by user
# PRCFULLPAYMENT : Percent of full payment paid by user
# TENURE : Tenure of credit card service for user

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in d:\new folder\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in d:\new folder\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\new folder\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\new folder\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\new folder\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\new folder\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install matplot
# Out:
# Collecting matplot
#   Downloading matplot-0.1.9-py2.py3-none-any.whl.metadata (241 bytes)
# Collecting pyloco>=0.0.134 (from matplot)
#   Downloading pyloco-0.0.139-py2.py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: matplotlib>=3.1.1 in d:\new folder\lib\site-packages (from matplot) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in d:\new folder\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\new folder\lib\site-packages (from matplotlib>=3.1.1->matplot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\new folder\lib\site-packages (from matplotlib>=3.1.1->matplot) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\new folder\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in d:\new folder\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in d:\new folder\lib\site-packages (from matplotlib>=3.1.1->matplot) (23.2)
# Requirement already satisfied: pillow>=8 in d:\new folder\lib\site-packages (from matplotlib>=3.1.1->matplot) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\new folder\lib\site-packages (from matplotlib>=3.1.1->matplot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\new folder\lib\site-packages (from matplotlib>=3.1.1->matplot) (2.9.0.post0)
# Collecting ushlex (from pyloco>=0.0.134->matplot)
#   Downloading ushlex-0.99.1.tar.gz (4.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: websocket-client in d:\new folder\lib\site-packages (from pyloco>=0.0.134->matplot) (1.8.0)
# Collecting twine (from pyloco>=0.0.134->matplot)
#   Downloading twine-5.1.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting typing (from pyloco>=0.0.134->matplot)
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      ---------------------------------------- 0.0/78.6 kB ? eta -:--:--
#      ---------------------------------------- 78.6/78.6 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting SimpleWebSocketServer (from pyloco>=0.0.134->matplot)
#   Downloading SimpleWebSocketServer-0.1.2.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six>=1.5 in d:\new folder\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->matplot) (1.16.0)
# Requirement already satisfied: pkginfo>=1.8.1 in d:\new folder\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.10.0)
# Collecting readme-renderer>=35.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading readme_renderer-44.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests>=2.20 in d:\new folder\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.32.2)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in d:\new folder\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in d:\new folder\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.2.2)
# Requirement already satisfied: importlib-metadata>=3.6 in d:\new folder\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (7.0.1)
# Requirement already satisfied: keyring>=15.1 in d:\new folder\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (24.3.1)
# Collecting rfc3986>=1.4.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: rich>=12.0.0 in d:\new folder\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (13.3.5)
# Requirement already satisfied: zipp>=0.5 in d:\new folder\lib\site-packages (from importlib-metadata>=3.6->twine->pyloco>=0.0.134->matplot) (3.17.0)
# Requirement already satisfied: jaraco.classes in d:\new folder\lib\site-packages (from keyring>=15.1->twine->pyloco>=0.0.134->matplot) (3.2.1)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in d:\new folder\lib\site-packages (from keyring>=15.1->twine->pyloco>=0.0.134->matplot) (0.2.2)
# Collecting nh3>=0.2.14 (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot)
#   Downloading nh3-0.2.18-cp37-abi3-win_amd64.whl.metadata (1.8 kB)
# Collecting docutils>=0.21.2 (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot)
#   Downloading docutils-0.21.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: Pygments>=2.5.1 in d:\new folder\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\new folder\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\new folder\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in d:\new folder\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2024.6.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in d:\new folder\lib\site-packages (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (2.2.0)
# Requirement already satisfied: mdurl~=0.1 in d:\new folder\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (0.1.0)
# Requirement already satisfied: more-itertools in d:\new folder\lib\site-packages (from jaraco.classes->keyring>=15.1->twine->pyloco>=0.0.134->matplot) (10.1.0)
# Downloading matplot-0.1.9-py2.py3-none-any.whl (5.0 kB)
# Downloading pyloco-0.0.139-py2.py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.2 kB ? eta -:--:--
#    ---------------------------------------- 60.2/60.2 kB 3.3 MB/s eta 0:00:00
# Downloading twine-5.1.1-py3-none-any.whl (38 kB)
# Downloading readme_renderer-44.0-py3-none-any.whl (13 kB)
# Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Downloading docutils-0.21.2-py3-none-any.whl (587 kB)
#    ---------------------------------------- 0.0/587.4 kB ? eta -:--:--
#    ------------------- -------------------- 286.7/587.4 kB 8.6 MB/s eta 0:00:01
#    ---------------------------------------- 587.4/587.4 kB 7.3 MB/s eta 0:00:00
# Downloading nh3-0.2.18-cp37-abi3-win_amd64.whl (579 kB)
#    ---------------------------------------- 0.0/579.0 kB ? eta -:--:--
#    ---------------------------- ----------- 409.6/579.0 kB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 579.0/579.0 kB 7.3 MB/s eta 0:00:00
# Building wheels for collected packages: SimpleWebSocketServer, typing, ushlex
#   Building wheel for SimpleWebSocketServer (setup.py): started
#   Building wheel for SimpleWebSocketServer (setup.py): finished with status 'done'
#   Created wheel for SimpleWebSocketServer: filename=SimpleWebSocketServer-0.1.2-py3-none-any.whl size=9688 sha256=57ce074ec9bac22c11dc2efb8a728876ba730ba76137c4bf2c65b57c7d34e033
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\81\fd\d8\f145b47bedceb5dff96b76e404a4ee9be956a4f8f150cd8133
#   Building wheel for typing (setup.py): started
#   Building wheel for typing (setup.py): finished with status 'done'
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26327 sha256=5842c304b31d61af4992ed5ba23588cb9961c3ce258d0e1a82f1446aa7c52919
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\12\98\52\2bffe242a9a487f00886e43b8ed8dac46456702e11a0d6abef
#   Building wheel for ushlex (setup.py): started
#   Building wheel for ushlex (setup.py): finished with status 'done'
#   Created wheel for ushlex: filename=ushlex-0.99.1-py3-none-any.whl size=4400 sha256=f10981004a6e08aa21c46374417bc90decd82046f9eb18d83a17003b48639d7e
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\42\29\49\bde2276505cc99295263e8ab2fbfd83162b3380b4b571b03bc
# Successfully built SimpleWebSocketServer typing ushlex
# Installing collected packages: ushlex, SimpleWebSocketServer, nh3, typing, rfc3986, docutils, readme-renderer, twine, pyloco, matplot
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.18.1
#     Uninstalling docutils-0.18.1:
#       Successfully uninstalled docutils-0.18.1
# Successfully installed SimpleWebSocketServer-0.1.2 docutils-0.21.2 matplot-0.1.9 nh3-0.2.18 pyloco-0.0.139 readme-renderer-44.0 rfc3986-2.0.0 twine-5.1.1 typing-3.7.4.3 ushlex-0.99.1

# %% [markdown]
# # import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans,AgglomerativeClustering,DBSCAN,SpectralClustering
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_samples, silhouette_score

# %% [markdown]
# #Load Data set

# %%
creditcard = pd.read_csv("C:\\Users\\HP\\Downloads\\credit_card_dataset.csv")
creditcard.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %% [markdown]
# 4.Exploratory Data Analysis & Data Cleaning:

# %%
creditcard.shape
# Out:
# (8950, 18)

# %%
creditcard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
creditcard.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.637500   1113.821139             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 8950.000000                       8950.000000
# mean                     0.202458                          0.364437
# std                      0.298336                          0.397448
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count             8950.000000       8950.000000    8950.000000   8949.000000
# mean                 0.135144          3.248827      14.709832   4494.449450
# std                  0.200121          6.824647      24.857649   3638.815725
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE
# count   8950.000000       8637.000000       8950.000000  8950.000000
# mean    1733.143852        864.206542          0.153715    11.517318
# std     2895.063757       2372.446607          0.292499     1.338331
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.276166        169.123707          0.000000    12.000000
# 50%      856.901546        312.343947          0.000000    12.000000
# 75%     1901.134317        825.485459          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %%
creditcard.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
# find all columns having missing values
missing_var = [var for var in creditcard.columns if creditcard[var].isnull().sum()>0]
missing_var
# Out:
# ['CREDIT_LIMIT', 'MINIMUM_PAYMENTS']

# %%
# fill mean value in place of missing values
creditcard["MINIMUM_PAYMENTS"] = creditcard["MINIMUM_PAYMENTS"].fillna(creditcard["MINIMUM_PAYMENTS"].mean())
creditcard["CREDIT_LIMIT"] = creditcard["CREDIT_LIMIT"].fillna(creditcard["CREDIT_LIMIT"].mean())

# %%
creditcard.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
# check duplicate entries in the dataset
creditcard.duplicated().sum()
# Out:
# 0

# %%
# drop unnecessary columns
creditcard.drop(columns=["CUST_ID"],axis=1,inplace=True)

# %%
creditcard.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE'],
#       dtype='object')

# %%
creditcard.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000        864.206542          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %% [markdown]
# Outliear Detection

# %%
# find outlier in all columns
for i in creditcard.select_dtypes(include=['float64','int64']).columns:
  max_thresold = creditcard[i].quantile(0.95)
  min_thresold = creditcard[i].quantile(0.05)
  creditcard_no_outlier = creditcard[(creditcard[i] < max_thresold) & (creditcard[i] > min_thresold)].shape
  print(" outlier in ",i,"is" ,int(((creditcard.shape[0]-creditcard_no_outlier[0])/creditcard.shape[0])*100),"%")
# Out:
#  outlier in  BALANCE is 10 %
#  outlier in  BALANCE_FREQUENCY is 75 %
#  outlier in  PURCHASES is 27 %
#  outlier in  ONEOFF_PURCHASES is 53 %
#  outlier in  INSTALLMENTS_PURCHASES is 48 %
#  outlier in  CASH_ADVANCE is 56 %
#  outlier in  PURCHASES_FREQUENCY is 47 %
#  outlier in  ONEOFF_PURCHASES_FREQUENCY is 53 %
#  outlier in  PURCHASES_INSTALLMENTS_FREQUENCY is 58 %
#  outlier in  CASH_ADVANCE_FREQUENCY is 57 %
#  outlier in  CASH_ADVANCE_TRX is 56 %
#  outlier in  PURCHASES_TRX is 27 %
#  outlier in  CREDIT_LIMIT is 14 %
#  outlier in  PAYMENTS is 10 %
#  outlier in  MINIMUM_PAYMENTS is 10 %
#  outlier in  PRC_FULL_PAYMENT is 71 %
#  outlier in  TENURE is 91 %

# %%
# remove outliers from columns having nearly 10% outlier
max_thresold_BALANCE = creditcard["BALANCE"].quantile(0.95)
min_thresold_BALANCE = creditcard["BALANCE"].quantile(0.05)
max_thresold_CREDIT_LIMIT = creditcard["CREDIT_LIMIT"].quantile(0.95)
min_thresold_CREDIT_LIMIT = creditcard["CREDIT_LIMIT"].quantile(0.05)
max_thresold_PAYMENTS = creditcard["PAYMENTS"].quantile(0.95)
min_thresold_PAYMENTS = creditcard["PAYMENTS"].quantile(0.05)
creditcard_no_outlier = creditcard[(creditcard["CREDIT_LIMIT"] < max_thresold_CREDIT_LIMIT) & (creditcard["CREDIT_LIMIT"] > min_thresold_CREDIT_LIMIT) & (creditcard["BALANCE"] < max_thresold_BALANCE) & (creditcard["BALANCE"] > min_thresold_BALANCE) &  (creditcard["PAYMENTS"] < max_thresold_PAYMENTS) & (creditcard["PAYMENTS"] > min_thresold_PAYMENTS)]

# %%
# DataFrame having no outlier
creditcard_no_outlier.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 4   817.714335           1.000000      16.00             16.00
# 5  1809.828751           1.000000    1333.28              0.00
# 7  1823.652743           1.000000     436.20              0.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 1                    0.00   6442.945483             0.000000
# 2                    0.00      0.000000             1.000000
# 4                    0.00      0.000000             0.083333
# 5                 1333.28      0.000000             0.666667
# 7                  436.20      0.000000             1.000000
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 4                    0.083333                          0.000000
# 5                    0.000000                          0.583333
# 7                    0.000000                          1.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 1                    0.25                 4              0        7000.0
# 2                    0.00                 0             12        7500.0
# 4                    0.00                 0              1        1200.0
# 5                    0.00                 0              8        1800.0
# 7                    0.00                 0             12        2300.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 4   678.334763        244.791237          0.000000      12
# 5  1400.057770       2407.246035          0.000000      12
# 7   679.065082        532.033990          0.000000      12

# %%
creditcard_no_outlier.shape
# Out:
# (6466, 17)

# %%
# correlation matrix of DataFrame
plt.figure(figsize=(20,10))
corn=creditcard_no_outlier.corr()
sns.heatmap(corn,annot=True,cmap="BuPu",fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# 6. Scaling the data

# %% [markdown]
# The next step is to scale our values to give them all equal importance. Scaling is also important from a clustering perspective as the distance between points affects the way clusters are formed.
#
# Using the StandardScaler, we transform our dataframe into the following numpy arrays

# %%
# scale the DataFrame
scalar=StandardScaler()
creditcard_scaled = scalar.fit_transform(creditcard_no_outlier)
creditcard_scaled
# Out:
# array([[ 1.35958568, -0.02715353, -0.71136663, ...,  0.18339488,
#          0.24802861,  0.33969475],
#        [ 0.84268315,  0.48108734, -0.05912009, ..., -0.04878463,
#         -0.51957586,  0.33969475],
#        [-0.38317207,  0.48108734, -0.69786902, ..., -0.24832644,
#         -0.51957586,  0.33969475],
#        ...,
#        [-0.94653953, -0.45069038, -0.51244565, ..., -0.32934159,
#          1.783241  , -4.58327778],
#        [-0.96594456, -0.45069038, -0.61814878, ..., -0.34163245,
#          1.20753592, -4.58327778],
#        [-0.92315108, -2.31424023, -0.71136663, ..., -0.36464695,
#          0.63183085, -4.58327778]])

# %% [markdown]
# 7. Dimensionality reduction

# %% [markdown]
# -> Dimensionality reduction is a technique used to reduce the number of features in a dataset while retaining as much of the important information as possible.
#
# -> In other words, it is a process of transforming high-dimensional data into a lower-dimensional space that still preserves the essence of the original data.
#
# -> This can be done for a variety of reasons, such as to reduce the complexity of a model, to reduce the storage space, to improve the performance of a learning algorithm, or to make it easier to visualize the data.
#
# -> There are several techniques for dimensionality reduction,
#
# including principal component analysis (PCA),
# singular value decomposition (SVD),
# and linear discriminant analysis (LDA).
# Each technique uses a different method to project the data onto a lower-dimensional space while preserving important information.

# %%
# convert the DataFrame into 2D DataFrame for visualization
pca = PCA(n_components=2)
principal_comp = pca.fit_transform(creditcard_scaled)
pca_df = pd.DataFrame(data=principal_comp,columns=["pca1","pca2"])
pca_df.head()
# Out:
#        pca1      pca2
# 0 -2.286560  3.004153
# 1  1.134733  0.431811
# 2 -1.458103 -1.493162
# 3  0.740703 -0.539548
# 4  0.648375 -1.077195

# %% [markdown]
# 8. Hyperparameter tuning

# %%
# find 'k' value by Elbow Method
inertia = []
range_val = range(1,15)
for i in range_val:
  kmean = KMeans(n_clusters=i)
  kmean.fit_predict(pd.DataFrame(creditcard_scaled))
  inertia.append(kmean.inertia_)
plt.plot(range_val,inertia,'bx-')
plt.xlabel('Values of K') 
plt.ylabel('Inertia') 
plt.title('The Elbow Method using Inertia') 
plt.show()

# %% [markdown]
# From this plot, 4th cluster seems to be the elbow of the curve. However, the values does not reduce to linearly until 8th cluster, so we may consider using 8 clusters in this case.

# %% [markdown]
# 9. Model Building
# ** K-Means Clustering**

# %%
# apply kmeans algorithm
kmeans_model=KMeans(4)
kmeans_model.fit_predict(creditcard_scaled)
pca_df_kmeans= pd.concat([pca_df,pd.DataFrame({'cluster':kmeans_model.labels_})],axis=1)

# %%
# visualize the clustered dataframe
# Scatter Plot
plt.figure(figsize=(8,8))
#palette=['dodgerblue','red','green','blue','black','pink','gray','purple','coolwarm']
ax=sns.scatterplot(x="pca1",y="pca2",hue="cluster",data=pca_df_kmeans,palette=['red','green','blue','black'])
plt.title("Clustering using K-Means Algorithm")
plt.show()

# %% [markdown]
# 9.1. Analyzing Clustering Output
# We've used K-Means model for clustering in this dataset.

# %%
kmeans_model.cluster_centers_.shape
# Out:
# (4, 17)

# %%
# find all cluster centers
cluster_centers = pd.DataFrame(data=kmeans_model.cluster_centers_,columns=[creditcard_df.columns])
# inverse transfor the data
cluster_centers = scalar.inverse_transform(cluster_centers)
cluster_centers = pd.DataFrame(data=cluster_centers,columns=[creditcard_df.columns])
cluster_centers
# Out:
#        BALANCE BALANCE_FREQUENCY    PURCHASES ONEOFF_PURCHASES  \
# 0  1630.758841          0.975799  3261.720110      2097.914118
# 1   666.536661          0.919620   859.937972       287.393484
# 2  1214.952667          0.874918   280.255441       235.942200
# 3  2869.662491          0.956336   305.379411       201.672397
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0            1164.601336   310.510032            0.921965
# 1             572.947129   144.474524            0.840478
# 2              44.500057   534.074341            0.171233
# 3             103.742882  3207.526662            0.234171
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   0.661812                         0.686219
# 1                   0.204251                         0.694923
# 2                   0.106097                         0.064550
# 3                   0.114863                         0.136192
#
#   CASH_ADVANCE_FREQUENCY CASH_ADVANCE_TRX PURCHASES_TRX CREDIT_LIMIT  \
# 0               0.055309         1.118873     48.025735  6070.014483
# 1               0.031089         0.543851     17.595786  3821.495232
# 2               0.112084         1.968573      3.128360  3209.769027
# 3               0.467998        12.528926      5.028926  5113.119835
#
#       PAYMENTS MINIMUM_PAYMENTS PRC_FULL_PAYMENT     TENURE
# 0  2783.102522       911.926181         0.257198  11.870098
# 1  1005.441583       516.569786         0.301043  11.710926
# 2   910.198114       662.500303         0.044371  11.567209
# 3  1866.633714      1149.345280         0.032142  11.134298

# %%
# create a column as "cluster" & store the respective cluster name that they belongs to
creditcard_cluster_df = pd.concat([creditcard_df,pd.DataFrame({'cluster':kmeans_model.labels_})],axis=1)
creditcard_cluster_df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  cluster
# 0   201.802084        139.509787          0.000000      12      3.0
# 1  4103.032597       1072.340217          0.222222      12      1.0
# 2   622.066742        627.284787          0.000000      12      2.0
# 3     0.000000        864.206542          0.000000      12      1.0
# 4   678.334763        244.791237          0.000000      12      1.0

# %% [markdown]
# 9.2 Outcome
# -> There are 4 clusters (segments)- each clusters are shown below in detail:
#
# First Customers cluster (Transactors): Those are customers who pay least amount of interest charges and careful with their money, Cluster with lowest balance (104 Dollar) and cash advance (303 Dollar), Percentage of full payment = 23%
#
# Second customers cluster (revolvers) who use credit card as a loan (most lucrative sector): highest balance (5000 Dollar) and cash advance (5000 Dollar), low purchase frequency, high cash advance frequency (0.5), high cash advance transactions (16) and low percentage of full payment (3%)
#
# Third customer cluster (VIP/Prime): high credit limit 16K Dollar and highest percentage of full payment, target for increase credit limit and increase spending habits
#
# Fourth customer cluster (low tenure): these are customers with low tenure (7 years), low balance

# %% [markdown]
# 9.3. Analysis of each Cluster
# Cluster - 1

# %%
cluster_1 = creditcard_cluster[creditcard_cluster["cluster"]==0]
cluster_1.sort_values(by=['BALANCE'], ascending=False).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 cluster_1 = creditcard_cluster[creditcard_cluster["cluster"]==0]
#       2 cluster_1.sort_values(by=['BALANCE'], ascending=False).head()
#
# NameError: name 'creditcard_cluster' is not defined
